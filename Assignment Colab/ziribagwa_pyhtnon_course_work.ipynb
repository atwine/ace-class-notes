# %%
import pandas as pd # iimporting the pandas library

# %%
pwd # cheacking the present working directory
# Out:
# '/home/ace/Downloads'

# %%
ls # checking what is the working directoty
# Out:
# 'Assignment-Importing data in python.docx'
#  Assignnmet06032020.zip
#  Class06032020.py
#  FL_insurance_sample.csv
#  FL_insurance_sample.csv.zip
#  FMS_data2.xlsx
#  FMS_data.txt
#  fms.Rdata
#  pandas_tutorial_read.csv
#  Peter_python_exercise.zip
#  reznick2018_Is_evolution_predictable.pdf
#  sequence.fasta
# '~$signment-Importing data in python.docx'
#  Species_evolution_review.pdf
#  Untitled1.py
#  ziribagwa_pyhtnon_course_work.html

# %%
mydata= pd.read_csv("FL_insurance_sample.csv") # import the csv file using pandas
mydata.head() # display the first 5 rows
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
mydata = pd.read_csv("http://winterolympicsmedals.com/medals.csv")

# %%
mydata2 = pd.read_table("FMS_data.txt") # read a text_file in form of a table
mydata2.head() # show the top first 5 rows
# Out:
#    id acdc_rs1501299 ace_id actn3_r577x actn3_rs540874 actn3_rs1815739  \
# 0   1        FA-1801     CA          DD             CC              GG
# 1   2        FA-1802     CA          ID             CT              GA
# 2   3        FA-1803     CA          ID             CT              GA
# 3   4        FA-1804     CC          DD             CT              GA
# 4   5        FA-1805     CA          ID             CC              GG
#
#   actn3_1671064 ardb1_1801253 adrb2_1042713 adrb2_1042714     ...       \
# 0            CC            AA           NaN            GA     ...
# 1            TC            GA           NaN            GA     ...
# 2            TC            GA           NaN            GA     ...
# 3            TC            GA           NaN            AA     ...
# 4            CC            AA           NaN            GA     ...
#
#   D_Pre_BM_VOL  D_Pre_M_VOL  D_Pre_B_VOL D_Post_WA_VOL D_Post_WM_VOL  \
# ...

# %%
mydata3 = pd.read_csv("FMS_data.txt", sep ="\t") # read a text_file in form of a CSV
mydata3.head()
# Out:
#    id acdc_rs1501299 ace_id actn3_r577x actn3_rs540874 actn3_rs1815739  \
# 0   1        FA-1801     CA          DD             CC              GG
# 1   2        FA-1802     CA          ID             CT              GA
# 2   3        FA-1803     CA          ID             CT              GA
# 3   4        FA-1804     CC          DD             CT              GA
# 4   5        FA-1805     CA          ID             CC              GG
#
#   actn3_1671064 ardb1_1801253 adrb2_1042713 adrb2_1042714     ...       \
# 0            CC            AA           NaN            GA     ...
# 1            TC            GA           NaN            GA     ...
# 2            TC            GA           NaN            GA     ...
# 3            TC            GA           NaN            AA     ...
# 4            CC            AA           NaN            GA     ...
#
#   D_Pre_BM_VOL  D_Pre_M_VOL  D_Pre_B_VOL D_Post_WA_VOL D_Post_WM_VOL  \
# ...
